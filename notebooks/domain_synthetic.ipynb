# %% [markdown]
# # Domain synthetic experiments (local or Colab)
#
# Results: `results/baseline/<experiment>/<timestamp>/`
#
# **Colab:** run Drive + install cells first, then experiments.

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

# %%
if IN_COLAB:
    # %cd /content/drive/MyDrive/synthetic-exps/
    # !sudo apt-get update -qq && sudo apt-get install -y -qq zstd
    # !curl -fsSL https://ollama.com/install.sh | sh
    # !pip install -q -e ".[llm]"
    # !ollama pull llama3:8b-instruct-q4_K_M

# %%
import sys
from pathlib import Path
ROOT = Path.cwd()
if not (ROOT / "routers").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
from dotenv import load_dotenv
load_dotenv(ROOT / ".env")
from routers.synthetic.ollama_server import ensure_ollama_server
ensure_ollama_server(wait_seconds=120)

# %% [markdown]
# ## Exp 1 — Baseline

# %%
from routers.experiments import exp01_baseline as exp01
exp01.run(save=True, rebuild_splits=False)

# %% [markdown]
# ## Exp 2 — Failure synthetic

# %%
from routers.experiments import exp02_failure_synth as exp02
exp02.run(save=True)
